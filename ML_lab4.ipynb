# %% [markdown]
# <a href="https://colab.research.google.com/github/2403A51355/ml_lab/blob/main/ML_lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Salary_dataset.csv")
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.tail()
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
x=df.YearsExperience
y=df.Salary

# %%
import numpy as np

# %%
x=np.array(x).reshape(-1,1)
y=np.array(y).reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train ,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
print("actual salary",y_test[:5])
print("predicted salary",y_pred[:5])
# Out:
# actual salary [[112636.]
#  [ 67939.]
#  [113813.]
#  [ 83089.]
#  [ 64446.]]
# predicted salary [[115791.21011287]
#  [ 71499.27809463]
#  [102597.86866063]
#  [ 75268.80422384]
#  [ 55478.79204548]]

# %%
from sklearn.metrics import mean_squared_error

# %%
 mse=mean_squared_error(y_test,y_pred)
 mse
# Out:
# 49830096.855908394

# %%
rmse=np.sqrt(mse)
print("root mean squared error:",rmse)
# Out:
# root mean squared error: 7059.04362190151

# %%
from sklearn.metrics import r2_score

# %%
r2=r2_score(y_test,y_pred)
print("r.squared value:",r2)
# Out:
# r.squared value: 0.9024461774180497

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,y_pred)

plt.xlabel("years of experience")
plt.ylabel("salary")
plt.title("salary vs experience")
plt.show()

# %%
plt.scatter(x_test,y_test,label="actual salary")
plt.scatter(x_test,y_pred,label="predicted salary")

plt.xlabel("actual salary")
plt.ylabel("predicted salary")
plt.title("actual vs predciited salary")
plt.legend()
plt.show()

# %%
slope=model.coef_
intercept=model.intercept_
print("slope (m):",slope)
print("intercept (c):",intercept)
# Out:
# slope (m): [[9423.81532303]]
# intercept (c): [24380.20147947]

# %%
experience=[[5]]

# %%
predicted_salary=model.predict(experience)
print("predicted salary for 5 years of experience:",predicted_salary)
# Out:
# predicted salary for 5 years of experience: [[71499.27809463]]
